# %% [markdown]
# This notebook illustrates the basic usage of the provided code for the "Programmable Cubes" challenge as part of SPoC 2024.
#
# It covers:
# - setting up the three different problems
# - creating and cleaning chromosomes
# - visualisation
# - animation

# %% [markdown]
# ### First, lets load some packages...

# %%
import seaborn as sns
# %matplotlib notebook
from matplotlib.animation import FuncAnimation
import matplotlib.pyplot as plt

from programmable_cubes_UDP import programmable_cubes_UDP, ProgrammableCubes
from pygmo import problem
import pygmo
import numpy as np
from copy import deepcopy
from tqdm import tqdm
import json

# %% [markdown]
# ### We start with the ISS first!

# %% [markdown]
# The following demonstrates how to:
#
# - create a random chromosome
# - create a problem instance
# - evaluate the chromosome with the problem instance
#
# The fitness you obtain here is the same the optimize platform will show!

# %%
# simple function for creating a random chromosome
def create_random_chromosome():
    chrom = []
    for i in range(6000):
        # select a cube randomly
        cube_id = np.random.randint(148)
        # select a maneuver randomly
        move = np.random.randint(6)
        
        # add command to chromosome
        chrom += [cube_id, move]
    # chromosome always ends with -1
    chrom += [-1]
    return np.array(chrom)

# create a random chromosome
chromosome = create_random_chromosome()

# create a problem instance for the ISS
udp = programmable_cubes_UDP('ISS')
prob = problem(udp)

# evaluate the fitness of the chromosome (checks formatting of the chromosome as well)
prob.fitness(chromosome)
# Out:
# array([0.18606702])

# %% [markdown]
# You can also directly evaluate the chromosome using the UDP. This way, you can use some of the convenience functions of the udp instance to analyse your solution!

# %%
udp.fitness(chromosome)
# Out:
# [0.18606701940035278]

# %% [markdown]
# One of them is plotting: here, we plot the target configuration. You can specify which cube types to plot with a list (e.g., here we only plot cubes with type '2').

# %%
udp.plot('target', [2])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Plotting all three cube types gives us the ISS

# %%
udp.plot('target', [0, 1, 2])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# We can also plot the ensemble after applying the chromosome.

# %%
udp.plot('ensemble', [0, 1, 2])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# After running the fitness function, the final cube positions can be accessed as follows. Note: re-running fitness overwrites this!

# %%
udp.final_cube_positions
# Out:
# array([[ 3,  3,  0],
#        [ 7,  5,  6],
#        [11,  4,  5],
#        [ 5,  3,  2],
#        [ 4,  5,  5],
#        [11,  3,  3],
#        [ 4,  6,  5],
#        [ 2,  2,  5],
#        [ 0,  5,  5],
#        [ 8,  5,  5],
#        [10,  2, -2],
#        [ 8,  2, -2],
#        [10,  5,  7],
#        [ 9,  2, -2],
#        [ 2,  3,  5],
#        [12,  7,  0],
#        [ 7,  1,  3],
#        [ 1,  7,  4],
#        [ 5,  2,  4],
#        [ 9,  8,  6],
#        [ 8,  4,  1],
#        [10,  5,  2],
#        [-1,  3,  0],
#        [ 3,  3,  1],
#        [ 8,  1, -2],
#        [ 9,  3,  4],
#        [-1,  3,  1],
#        [ 6,  3,  3],
#        [12,  3,  2],
#        [ 6,  5,  5],
#        [ 8,  5,  6],
#        [ 8,  3,  2],
#        [ 0,  2,  1],
#        [ 8,  3,  1],
#        [ 9,  6,  6],
#        [11,  5,  7],
#        [11,  5,  6],
#        [ 4,  5,  7],
#        [ 6,  4,  3],
#        [11,  7,  1],
#        [ 5,  3,  1],
#        [-1,  5,  5],
#        [ 4,  8,  6],
#        [ 6,  3,  4],
#        [12,  8,  1],
#        [ 0,  5,  6],
#        [ 9,  2, -1],
#        [ 6,  1,  4],
#        [-1,  6,  5],
#        [ 6,  3,  5],
#        [12,  3,  1],
#        [ 0,  2,  2],
#        [ 8,  8,  5],
#        [ 8,  6,  6],
#        [12,  5,  1],
#        [ 3,  5,  7],
#        [11,  5,  8],
#        [ 0,  5,  3],
#        [ 2,  5,  5],
#        [ 4,  4,  4],
#        [ 8,  5,  4],
#        [ 5,  5,  8],
#        [ 6,  2,  4],
#        [ 4,  3,  1],
#        [ 2,  4,  5],
#        [ 0,  2,  3],
#        [-1,  2,  2],
#        [ 7,  4,  5],
#        [10,  5,  6],
#        [12,  7,  1],
#        [-1,  5,  3],
#        [ 7,  4,  1],
#        [ 3,  7,  4],
#        [ 8, -1, -2],
#        [12,  5,  0],
#        [ 8,  2, -1],
#        [ 0,  5,  4],
#        [ 5,  5,  7],
#        [ 0,  4,  6],
#        [12,  3,  0],
#        [10,  5,  1],
#        [ 4,  4,  5],
#        [ 2,  8,  4],
#        [ 3,  2,  5],
#        [-1,  1,  3],
#        [ 2,  5,  4],
#        [ 6,  2,  5],
#        [-1,  6,  2],
#        [10,  7,  1],
#        [ 4,  4,  3],
#        [ 4,  7,  5],
#        [12,  6,  0],
#        [ 9,  5,  6],
#        [ 6,  4,  0],
#        [ 6,  1,  3],
#        [11,  5,  9],
#        [ 5,  5,  6],
#        [ 2,  7,  4],
#        [ 9,  8,  5],
#        [ 6,  1,  2],
#        [-1,  2,  1],
#        [ 8,  5,  1],
#        [10,  6,  2],
#        [ 8,  3,  0],
#        [ 8,  3,  4],
#        [10,  6,  1],
#        [12,  4,  0],
#        [ 2,  6,  6],
#        [ 4,  7,  4],
#        [ 2,  3,  2],
#        [10,  7,  0],
#        [ 3,  3,  2],
#        [11,  3,  4],
#        [ 5,  5,  5],
#        [ 3,  5,  5],
#        [ 2,  4,  2],
#        [ 4,  8,  5],
#        [ 1,  2,  1],
#        [ 2,  3,  1],
#        [11,  3,  2],
#        [ 8,  3,  3],
#        [12,  4, -1],
#        [ 0,  4,  5],
#        [ 1,  4,  5],
#        [ 4,  4,  2],
#        [ 4,  2,  4],
#        [ 8,  3, -2],
#        [ 2,  2,  1],
#        [-1,  5,  2],
#        [10,  3,  4],
#        [ 6,  4,  1],
#        [11,  4,  7],
#        [ 8,  3, -1],
#        [ 7,  4,  4],
#        [ 8,  1, -1],
#        [ 9,  8,  7],
#        [ 5,  4,  6],
#        [ 0,  1,  3],
#        [ 7,  3,  3],
#        [ 9,  7,  6],
#        [ 4,  3,  4],
#        [ 2,  5,  6],
#        [ 6,  3,  1],
#        [ 6,  3,  6],
#        [ 7,  5,  5],
#        [ 8,  0, -2],
#        [11,  6,  2],
#        [11,  4,  6]])

# %% [markdown]
# Cube types and target configuration are accessed as follows:

# %%
initial_types = udp.initial_cube_types
target_types = udp.target_cube_types
target_positions = udp.target_cube_positions

# %% [markdown]
# To plot the intial configuration, we use a chromosome which keeps the cube ensemble unchanged.

# %%
udp.fitness(np.array([-1]))
udp.plot('ensemble', [0, 1, 2])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### In the previous example, lots of moves were actually not realisable
#
# This can be seen by running the pretty function! Many of the cube/maneuver combinations would either disconnect the ensemble or the cube is physically not able to move / move without colliding with another cube.

# %%
udp.pretty(chromosome)
# Out:
# 0 -- Cannot apply move 4 to cube 78. Cube is connecting. Skipping command...
# 2 -- Cannot apply move 4 to cube 43. Cube is connecting. Skipping command...
# 3 -- Cannot apply move 0 to cube 64. Cube is connecting. Skipping command...
# 7 -- Cannot apply move 3 to cube 138. Cube is connecting. Skipping command...
# 11 -- Cannot apply move 2 to cube 147. Cube is connecting. Skipping command...
# 12 -- Cannot apply move 2 to cube 1. Cube would crash into neighbouring cubes. Skipping command...
# 13 -- Cannot apply move 2 to cube 113. Cube is connecting. Skipping command...
# 14 -- Cannot apply move 3 to cube 33. Cube is connecting. Skipping command...
# 15 -- Cannot apply move 5 to cube 83. Cube would crash into neighbouring cubes. Skipping command...
# 16 -- Cannot apply move 4 to cube 11. Cube is connecting. Skipping command...
# 17 -- Cannot apply move 3 to cube 100. Cube is connecting. Skipping command...
# 18 -- Cannot apply move 4 to cube 52. Cube is connecting. Skipping command...
# 19 -- Cannot apply move 1 to cube 125. Cube is connecting. Skipping command...
# 21 -- Cannot apply move 1 to cube 106. Cube would crash into neighbouring cubes. Skipping command...
# 23 -- Cannot apply move 2 to cube 1. Cube would crash into neighbouring cubes. Skipping command...
# 24 -- Cannot apply move 2 to cube 81. Cube is connecting. Skipping command...
# 26 -- Cannot apply move 0 to cube 64. Cube is connecting. Skipping command...
# 27 -- Cannot apply move 5 to cube 112. Cube would crash into neighbouring cubes. Skipping command...
# 28 -- Cannot apply move 3 to cube 90. Cube would crash into neighbouring cubes. Skipping command...
# 29 -- Cannot apply move 2 to cube 133. Cube is connecting. Skipping command...
# 30 -- Cannot apply move 0 to cube 10. Cube would crash into neighbouring cubes. Skipping command...
# 31 -- Cannot apply move 4 to cube 124. Cube is connecting. Skipping command...
# 33 -- Cannot apply move 3 to cube 22. Cube would crash into neighbouring cubes. Skipping command...
# 34 -- Cannot apply move 1 to cube 133. Cube is connecting. Skipping command...
# 35 -- Cannot apply move 1 to cube 91. Cube is connecting. Skipping command...
# 36 -- Cannot apply move 5 to cube 100. Cube is connecting. Skipping command...
# 38 -- Cannot apply move 1 to cube 79. Cube is connecting. Skipping command...
# 39 -- Cannot apply move 4 to cube 28. Cube is connecting. Skipping command...
# 40 -- Cannot apply move 0 to cube 79. Cube is connecting. Skipping command...
# 42 -- Cannot apply move 0 to cube 58. Cube is connecting. Skipping command...
# 44 -- Cannot apply move 5 to cube 107. Cube would crash into neighbouring cubes. Skipping command...
# 45 -- Cannot apply move 3 to cube 135. Cube is connecting. Skipping command...
# 47 -- Cannot apply move 3 to cube 108. Cube is connecting. Skipping command...
# 48 -- Cannot apply move 4 to cube 142. Cube is connecting. Skipping command...
# 49 -- Cannot apply move 4 to cube 49. Cube is connecting. Skipping command...
# 50 -- Cannot apply move 2 to cube 34. Cube is connecting. Skipping command...
# 51 -- Cannot apply move 4 to cube 144. Cube is connecting. Skipping command...
# 52 -- Cannot apply move 5 to cube 72. Cube is connecting. Skipping command...
# 54 -- Cannot apply move 1 to cube 60. Cube is connecting. Skipping command...
# 55 -- Cannot apply move 1 to cube 129. Cube is connecting. Skipping command...
# 57 -- Cannot apply move 1 to cube 96. Cube would crash into neighbouring cubes. Skipping command...
# 58 -- Cannot apply move 4 to cube 113. Cube is connecting. Skipping command...
# 59 -- Cannot apply move 4 to cube 58. Cube is connecting. Skipping command...
# 60 -- Cannot apply move 0 to cube 76. Cube would crash into neighbouring cubes. Skipping command...
# 61 -- Cannot apply move 3 to cube 3. Cube would crash into neighbouring cubes. Skipping command...
# 62 -- Cannot apply move 2 to cube 135. Cube is connecting. Skipping command...
# 63 -- Cannot apply move 1 to cube 88. Cube is connecting. Skipping command...
# 64 -- Cannot apply move 1 to cube 51. Cube is connecting. Skipping command...
# 65 -- Cannot apply move 1 to cube 44. Cube is connecting. Skipping command...
# 66 -- Cannot apply move 3 to cube 99. Cube is connecting. Skipping command...
# 67 -- Cannot apply move 3 to cube 138. Cube is connecting. Skipping command...
# 69 -- Cannot apply move 1 to cube 11. Cube is connecting. Skipping command...
# 70 -- Cannot apply move 5 to cube 125. Cube is connecting. Skipping command...
# 71 -- Cannot apply move 1 to cube 69. Cube is connecting. Skipping command...
# 72 -- Cannot apply move 2 to cube 60. Cube is connecting. Skipping command...
# 73 -- Cannot apply move 0 to cube 27. Cube is connecting. Skipping command...
# 74 -- Cannot apply move 4 to cube 34. Cube is connecting. Skipping command...
# 75 -- Cannot apply move 2 to cube 86. Cube would crash into neighbouring cubes. Skipping command...
# 76 -- Cannot apply move 5 to cube 69. Cube is connecting. Skipping command...
# 77 -- Cannot apply move 1 to cube 75. Cube is connecting. Skipping command...
# 78 -- Cannot apply move 2 to cube 136. Cube is connecting. Skipping command...
# 79 -- Cannot apply move 0 to cube 51. Cube is connecting. Skipping command...
# 80 -- Cannot apply move 0 to cube 63. Cube is connecting. Skipping command...
# 81 -- Cannot apply move 4 to cube 95. Cube would crash into neighbouring cubes. Skipping command...
# 82 -- Cannot apply move 0 to cube 108. Cube is connecting. Skipping command...
# 83 -- Cannot apply move 5 to cube 128. Cube would crash into neighbouring cubes. Skipping command...
# 84 -- Cannot apply move 4 to cube 60. Cube is connecting. Skipping command...
# 85 -- Cannot apply move 2 to cube 80. Cube is connecting. Skipping command...
# 86 -- Cannot apply move 5 to cube 63. Cube is connecting. Skipping command...
# 87 -- Cannot apply move 3 to cube 140. Cube is connecting. Skipping command...
# 88 -- Cannot apply move 5 to cube 13. Cube is connecting. Skipping command...
# 90 -- Cannot apply move 2 to cube 142. Cube is connecting. Skipping command...
# 91 -- Cannot apply move 3 to cube 126. Cube is connecting. Skipping command...
# 92 -- Cannot apply move 5 to cube 132. Cube is connecting. Skipping command...
# 93 -- Cannot apply move 4 to cube 144. Cube is connecting. Skipping command...
# 94 -- Cannot apply move 1 to cube 111. Cube would crash into neighbouring cubes. Skipping command...
# 95 -- Cannot apply move 3 to cube 13. Cube is connecting. Skipping command...
# 96 -- Cannot apply move 0 to cube 14. Cube is connecting. Skipping command...
# 97 -- Cannot apply move 0 to cube 126. Cube is connecting. Skipping command...
# 98 -- Cannot apply move 5 to cube 136. Cube is connecting. Skipping command...
# 99 -- Cannot apply move 2 to cube 12. Cube is connecting. Skipping command...
# 100 -- Cannot apply move 3 to cube 51. Cube is connecting. Skipping command...
# 104 -- Cannot apply move 4 to cube 9. Cube is connecting. Skipping command...
# 105 -- Cannot apply move 0 to cube 27. Cube is connecting. Skipping command...
# 107 -- Cannot apply move 4 to cube 143. Cube is connecting. Skipping command...
# 108 -- Cannot apply move 3 to cube 100. Cube is connecting. Skipping command...
# 110 -- Cannot apply move 4 to cube 115. Cube is connecting. Skipping command...
# 112 -- Cannot apply move 1 to cube 72. Cube is connecting. Skipping command...
# 115 -- Cannot apply move 0 to cube 76. Cube would crash into neighbouring cubes. Skipping command...
# 116 -- Cannot apply move 4 to cube 1. Cube would crash into neighbouring cubes. Skipping command...
# 117 -- Cannot apply move 0 to cube 37. Cube is connecting. Skipping command...
# 118 -- Cannot apply move 5 to cube 107. Cube is connecting. Skipping command...
# 119 -- Cannot apply move 1 to cube 51. Cube is connecting. Skipping command...
# 120 -- Cannot apply move 4 to cube 99. Cube is connecting. Skipping command...
# 121 -- Cannot apply move 5 to cube 87. Cube is connecting. Skipping command...
# 123 -- Cannot apply move 3 to cube 117. Cube is connecting. Skipping command...
# 124 -- Cannot apply move 2 to cube 15. Cube would crash into neighbouring cubes. Skipping command...
# 125 -- Cannot apply move 4 to cube 43. Cube is connecting. Skipping command...
# 126 -- Cannot apply move 2 to cube 97. Cube is connecting. Skipping command...
# 127 -- Cannot apply move 4 to cube 1. Cube would crash into neighbouring cubes. Skipping command...
# 128 -- Cannot apply move 3 to cube 16. Cube is connecting. Skipping command...
# 129 -- Cannot apply move 0 to cube 11. Cube is connecting. Skipping command...
# 130 -- Cannot apply move 3 to cube 94. Cube is connecting. Skipping command...
# 131 -- Cannot apply move 0 to cube 143. Cube is connecting. Skipping command...
# 132 -- Cannot apply move 2 to cube 131. Cube would crash into neighbouring cubes. Skipping command...
# 133 -- Cannot apply move 5 to cube 101. Cube would crash into neighbouring cubes. Skipping command...
# 134 -- Cannot apply move 4 to cube 89. Cube is connecting. Skipping command...
# 135 -- Cannot apply move 1 to cube 106. Cube would crash into neighbouring cubes. Skipping command...
# 136 -- Cannot apply move 3 to cube 120. Cube is connecting. Skipping command...
# 137 -- Cannot apply move 5 to cube 50. Cube would crash into neighbouring cubes. Skipping command...
# 138 -- Cannot apply move 1 to cube 79. Cube would crash into neighbouring cubes. Skipping command...
# 139 -- Cannot apply move 5 to cube 143. Cube is connecting. Skipping command...
# 141 -- Cannot apply move 4 to cube 33. Cube is connecting. Skipping command...
# 142 -- Cannot apply move 4 to cube 110. Cube would crash into neighbouring cubes. Skipping command...
# 143 -- Cannot apply move 3 to cube 8. Cube is connecting. Skipping command...
# 144 -- Cannot apply move 2 to cube 67. Cube is connecting. Skipping command...
# 145 -- Cannot apply move 5 to cube 120. Cube is connecting. Skipping command...
# 146 -- Cannot apply move 5 to cube 139. Cube would crash into neighbouring cubes. Skipping command...
# 147 -- Cannot apply move 2 to cube 52. Cube is connecting. Skipping command...
# 148 -- Cannot apply move 3 to cube 24. Cube is connecting. Skipping command...
# 150 -- Cannot apply move 0 to cube 3. Cube would crash into neighbouring cubes. Skipping command...
# 153 -- Cannot apply move 5 to cube 33. Cube is connecting. Skipping command...
# 155 -- Cannot apply move 3 to cube 5. Cube is connecting. Skipping command...
# 156 -- Cannot apply move 5 to cube 145. Cube is connecting. Skipping command...
# 157 -- Cannot apply move 2 to cube 92. Cube is connecting. Skipping command...
# 158 -- Cannot apply move 3 to cube 125. Cube is connecting. Skipping command...
# 159 -- Cannot apply move 2 to cube 118. Cube is connecting. Skipping command...
# 160 -- Cannot apply move 2 to cube 32. Cube is connecting. Skipping command...
# 161 -- Cannot apply move 3 to cube 90. Cube is connecting. Skipping command...
# 162 -- Cannot apply move 1 to cube 101. Cube would crash into neighbouring cubes. Skipping command...
# 163 -- Cannot apply move 5 to cube 91. Cube would crash into neighbouring cubes. Skipping command...
# 164 -- Cannot apply move 0 to cube 53. Cube is connecting. Skipping command...
# 165 -- Cannot apply move 2 to cube 9. Cube is connecting. Skipping command...
# 168 -- Cannot apply move 2 to cube 123. Cube is connecting. Skipping command...
# 170 -- Cannot apply move 2 to cube 66. Cube is connecting. Skipping command...
# 171 -- Cannot apply move 4 to cube 12. Cube is connecting. Skipping command...
# 173 -- Cannot apply move 1 to cube 41. Cube is connecting. Skipping command...
# 174 -- Cannot apply move 0 to cube 100. Cube is connecting. Skipping command...
# 175 -- Cannot apply move 2 to cube 37. Cube is connecting. Skipping command...
# 177 -- Cannot apply move 3 to cube 90. Cube is connecting. Skipping command...
# 180 -- Cannot apply move 5 to cube 123. Cube is connecting. Skipping command...
# 181 -- Cannot apply move 4 to cube 72. Cube is connecting. Skipping command...
# 182 -- Cannot apply move 1 to cube 91. Cube is connecting. Skipping command...
# 183 -- Cannot apply move 1 to cube 124. Cube is connecting. Skipping command...
# 185 -- Cannot apply move 1 to cube 100. Cube is connecting. Skipping command...
# 186 -- Cannot apply move 0 to cube 74. Cube is connecting. Skipping command...
# 187 -- Cannot apply move 0 to cube 85. Cube would crash into neighbouring cubes. Skipping command...
# 188 -- Cannot apply move 2 to cube 144. Cube is connecting. Skipping command...
# 189 -- Cannot apply move 2 to cube 9. Cube is connecting. Skipping command...
# 191 -- Cannot apply move 1 to cube 51. Cube is connecting. Skipping command...
# 193 -- Cannot apply move 0 to cube 128. Cube would crash into neighbouring cubes. Skipping command...
# 194 -- Cannot apply move 3 to cube 29. Cube is connecting. Skipping command...
# 196 -- Cannot apply move 2 to cube 118. Cube is connecting. Skipping command...
# 197 -- Cannot apply move 0 to cube 96. Cube is connecting. Skipping command...
# 198 -- Cannot apply move 2 to cube 60. Cube is connecting. Skipping command...
# 199 -- Cannot apply move 1 to cube 45. Cube is connecting. Skipping command...
# 200 -- Cannot apply move 2 to cube 121. Cube is connecting. Skipping command...
# 201 -- Cannot apply move 4 to cube 89. Cube is connecting. Skipping command...
# 202 -- Cannot apply move 1 to cube 132. Cube is connecting. Skipping command...
# 203 -- Cannot apply move 4 to cube 64. Cube is connecting. Skipping command...
# 204 -- Cannot apply move 2 to cube 118. Cube is connecting. Skipping command...
# 207 -- Cannot apply move 4 to cube 97. Cube is connecting. Skipping command...
# 209 -- Cannot apply move 3 to cube 41. Cube is connecting. Skipping command...
# 210 -- Cannot apply move 2 to cube 89. Cube is connecting. Skipping command...
# 211 -- Cannot apply move 4 to cube 49. Cube is connecting. Skipping command...
# 212 -- Cannot apply move 5 to cube 45. Cube is connecting. Skipping command...
# 213 -- Cannot apply move 4 to cube 25. Cube would crash into neighbouring cubes. Skipping command...
# 214 -- Cannot apply move 5 to cube 42. Cube would crash into neighbouring cubes. Skipping command...
# 215 -- Cannot apply move 0 to cube 31. Cube is connecting. Skipping command...
# 216 -- Cannot apply move 1 to cube 121. Cube is connecting. Skipping command...
# 220 -- Cannot apply move 4 to cube 29. Cube is connecting. Skipping command...
# 221 -- Cannot apply move 1 to cube 90. Cube is connecting. Skipping command...
# 223 -- Cannot apply move 0 to cube 75. Cube is connecting. Skipping command...
# 224 -- Cannot apply move 2 to cube 109. Cube is connecting. Skipping command...
# 225 -- Cannot apply move 4 to cube 61. Cube is connecting. Skipping command...
# 226 -- Cannot apply move 3 to cube 44. Cube is connecting. Skipping command...
# 227 -- Cannot apply move 1 to cube 120. Cube is connecting. Skipping command...
# 228 -- Cannot apply move 5 to cube 55. Cube is connecting. Skipping command...
# 229 -- Cannot apply move 5 to cube 38. Cube is connecting. Skipping command...
# 230 -- Cannot apply move 5 to cube 89. Cube is connecting. Skipping command...
# 232 -- Cannot apply move 0 to cube 47. Cube is connecting. Skipping command...
# 233 -- Cannot apply move 4 to cube 105. Cube is connecting. Skipping command...
# 235 -- Cannot apply move 3 to cube 72. Cube is connecting. Skipping command...
# 236 -- Cannot apply move 2 to cube 97. Cube is connecting. Skipping command...
# 239 -- Cannot apply move 4 to cube 106. Cube is connecting. Skipping command...
# 240 -- Cannot apply move 2 to cube 72. Cube is connecting. Skipping command...
# 242 -- Cannot apply move 0 to cube 44. Cube is connecting. Skipping command...
# 243 -- Cannot apply move 4 to cube 36. Cube would crash into neighbouring cubes. Skipping command...
# 244 -- Cannot apply move 0 to cube 106. Cube is connecting. Skipping command...
# 246 -- Cannot apply move 0 to cube 75. Cube is connecting. Skipping command...
# 247 -- Cannot apply move 4 to cube 114. Cube is connecting. Skipping command...
# 248 -- Cannot apply move 2 to cube 7. Cube would crash into neighbouring cubes. Skipping command...
# 249 -- Cannot apply move 1 to cube 99. Cube is connecting. Skipping command...
# 251 -- Cannot apply move 1 to cube 43. Cube is connecting. Skipping command...
# 252 -- Cannot apply move 3 to cube 74. Cube is connecting. Skipping command...
# 253 -- Cannot apply move 0 to cube 67. Cube is connecting. Skipping command...
# 254 -- Cannot apply move 5 to cube 84. Cube is connecting. Skipping command...
# 255 -- Cannot apply move 2 to cube 110. Cube would crash into neighbouring cubes. Skipping command...
# 256 -- Cannot apply move 2 to cube 133. Cube is connecting. Skipping command...
# 257 -- Cannot apply move 5 to cube 4. Cube is connecting. Skipping command...
# 258 -- Cannot apply move 2 to cube 94. Cube is connecting. Skipping command...
# 261 -- Cannot apply move 1 to cube 83. Cube would crash into neighbouring cubes. Skipping command...
# 264 -- Cannot apply move 5 to cube 61. Cube is connecting. Skipping command...
# 265 -- Cannot apply move 3 to cube 33. Cube is connecting. Skipping command...
# 266 -- Cannot apply move 3 to cube 87. Cube is connecting. Skipping command...
# 267 -- Cannot apply move 3 to cube 56. Cube is connecting. Skipping command...
# 268 -- Cannot apply move 4 to cube 44. Cube is connecting. Skipping command...
# 269 -- Cannot apply move 2 to cube 100. Cube is connecting. Skipping command...
# 270 -- Cannot apply move 1 to cube 5. Cube is connecting. Skipping command...
# 271 -- Cannot apply move 3 to cube 145. Cube is connecting. Skipping command...
# 272 -- Cannot apply move 3 to cube 65. Cube would crash into neighbouring cubes. Skipping command...
# 273 -- Cannot apply move 1 to cube 120. Cube is connecting. Skipping command...
# 274 -- Cannot apply move 0 to cube 72. Cube is connecting. Skipping command...
# 275 -- Cannot apply move 3 to cube 24. Cube is connecting. Skipping command...
# 276 -- Cannot apply move 4 to cube 49. Cube is connecting. Skipping command...
# 277 -- Cannot apply move 1 to cube 4. Cube is connecting. Skipping command...
# 278 -- Cannot apply move 3 to cube 71. Cube is connecting. Skipping command...
# 281 -- Cannot apply move 3 to cube 50. Cube is connecting. Skipping command...
# 282 -- Cannot apply move 2 to cube 97. Cube is connecting. Skipping command...
# 283 -- Cannot apply move 2 to cube 92. Cube is connecting. Skipping command...
# 286 -- Cannot apply move 3 to cube 80. Cube is connecting. Skipping command...
# 287 -- Cannot apply move 5 to cube 125. Cube is connecting. Skipping command...
# 288 -- Cannot apply move 5 to cube 27. Cube is connecting. Skipping command...
# 290 -- Cannot apply move 4 to cube 62. Cube is connecting. Skipping command...
# 294 -- Cannot apply move 5 to cube 99. Cube is connecting. Skipping command...
# 295 -- Cannot apply move 1 to cube 55. Cube is connecting. Skipping command...
# 296 -- Cannot apply move 3 to cube 145. Cube is connecting. Skipping command...
# 297 -- Cannot apply move 2 to cube 67. Cube is connecting. Skipping command...
# 298 -- Cannot apply move 2 to cube 81. Cube is connecting. Skipping command...
# 301 -- Cannot apply move 3 to cube 114. Cube is connecting. Skipping command...
# 302 -- Cannot apply move 1 to cube 6. Cube is connecting. Skipping command...
# 303 -- Cannot apply move 4 to cube 23. Cube is connecting. Skipping command...
# 304 -- Cannot apply move 3 to cube 113. Cube is connecting. Skipping command...
# 305 -- Cannot apply move 3 to cube 9. Cube is connecting. Skipping command...
# 306 -- Cannot apply move 1 to cube 9. Cube is connecting. Skipping command...
# 307 -- Cannot apply move 3 to cube 93. Cube would crash into neighbouring cubes. Skipping command...
# 308 -- Cannot apply move 0 to cube 99. Cube is connecting. Skipping command...
# 309 -- Cannot apply move 0 to cube 68. Cube is connecting. Skipping command...
# 311 -- Cannot apply move 3 to cube 123. Cube is connecting. Skipping command...
# 313 -- Cannot apply move 4 to cube 110. Cube would crash into neighbouring cubes. Skipping command...
# 314 -- Cannot apply move 3 to cube 96. Cube is connecting. Skipping command...
# 316 -- Cannot apply move 4 to cube 91. Cube is connecting. Skipping command...
# 317 -- Cannot apply move 5 to cube 34. Cube is connecting. Skipping command...
# 319 -- Cannot apply move 0 to cube 135. Cube is connecting. Skipping command...
# 320 -- Cannot apply move 1 to cube 81. Cube is connecting. Skipping command...
# 321 -- Cannot apply move 2 to cube 84. Cube is connecting. Skipping command...
# 322 -- Cannot apply move 0 to cube 103. Cube is connecting. Skipping command...
# 323 -- Cannot apply move 3 to cube 33. Cube is connecting. Skipping command...
# 324 -- Cannot apply move 0 to cube 33. Cube is connecting. Skipping command...
# 325 -- Cannot apply move 5 to cube 135. Cube is connecting. Skipping command...
# 326 -- Cannot apply move 3 to cube 56. Cube is connecting. Skipping command...
# 327 -- Cannot apply move 4 to cube 119. Cube would crash into neighbouring cubes. Skipping command...
# 328 -- Cannot apply move 0 to cube 91. Cube is connecting. Skipping command...
# 330 -- Cannot apply move 3 to cube 77. Cube is connecting. Skipping command...
# 331 -- Cannot apply move 4 to cube 90. Cube is connecting. Skipping command...
# 334 -- Cannot apply move 0 to cube 107. Cube is connecting. Skipping command...
# 337 -- Cannot apply move 0 to cube 72. Cube is connecting. Skipping command...
# 338 -- Cannot apply move 2 to cube 108. Cube is connecting. Skipping command...
# 339 -- Cannot apply move 4 to cube 69. Cube is connecting. Skipping command...
# 340 -- Cannot apply move 3 to cube 86. Cube would crash into neighbouring cubes. Skipping command...
# 342 -- Cannot apply move 0 to cube 2. Cube is connecting. Skipping command...
# 344 -- Cannot apply move 0 to cube 87. Cube is connecting. Skipping command...
# 345 -- Cannot apply move 0 to cube 31. Cube is connecting. Skipping command...
# 348 -- Cannot apply move 1 to cube 51. Cube is connecting. Skipping command...
# 349 -- Cannot apply move 5 to cube 26. Cube would crash into neighbouring cubes. Skipping command...
# 350 -- Cannot apply move 2 to cube 132. Cube is connecting. Skipping command...
# 351 -- Cannot apply move 1 to cube 125. Cube would crash into neighbouring cubes. Skipping command...
# 352 -- Cannot apply move 3 to cube 7. Cube is connecting. Skipping command...
# 354 -- Cannot apply move 4 to cube 50. Cube is connecting. Skipping command...
# 355 -- Cannot apply move 0 to cube 32. Cube is connecting. Skipping command...
# 356 -- Cannot apply move 3 to cube 65. Cube would crash into neighbouring cubes. Skipping command...
# 358 -- Cannot apply move 2 to cube 92. Cube is connecting. Skipping command...
# 360 -- Cannot apply move 3 to cube 113. Cube would crash into neighbouring cubes. Skipping command...
# 361 -- Cannot apply move 2 to cube 67. Cube is connecting. Skipping command...
# 362 -- Cannot apply move 5 to cube 4. Cube is connecting. Skipping command...
# 363 -- Cannot apply move 1 to cube 40. Cube is connecting. Skipping command...
# 364 -- Cannot apply move 2 to cube 16. Cube is connecting. Skipping command...
# 365 -- Cannot apply move 2 to cube 114. Cube is connecting. Skipping command...
# 366 -- Cannot apply move 2 to cube 114. Cube is connecting. Skipping command...
# 367 -- Cannot apply move 3 to cube 121. Cube is connecting. Skipping command...
# 370 -- Cannot apply move 4 to cube 9. Cube is connecting. Skipping command...
# 371 -- Cannot apply move 2 to cube 39. Cube is connecting. Skipping command...
# 372 -- Cannot apply move 2 to cube 94. Cube is connecting. Skipping command...
# 373 -- Cannot apply move 2 to cube 121. Cube is connecting. Skipping command...
# 374 -- Cannot apply move 0 to cube 142. Cube is connecting. Skipping command...
# 375 -- Cannot apply move 3 to cube 128. Cube is connecting. Skipping command...
# 377 -- Cannot apply move 3 to cube 9. Cube is connecting. Skipping command...
# 378 -- Cannot apply move 0 to cube 142. Cube is connecting. Skipping command...
# 379 -- Cannot apply move 2 to cube 24. Cube is connecting. Skipping command...
# 380 -- Cannot apply move 4 to cube 49. Cube is connecting. Skipping command...
# 381 -- Cannot apply move 0 to cube 102. Cube is connecting. Skipping command...
# 382 -- Cannot apply move 3 to cube 70. Cube is connecting. Skipping command...
# 383 -- Cannot apply move 4 to cube 107. Cube is connecting. Skipping command...
# 384 -- Cannot apply move 1 to cube 113. Cube would crash into neighbouring cubes. Skipping command...
# 385 -- Cannot apply move 1 to cube 103. Cube is connecting. Skipping command...
# 386 -- Cannot apply move 2 to cube 130. Cube would crash into neighbouring cubes. Skipping command...
# 387 -- Cannot apply move 4 to cube 50. Cube is connecting. Skipping command...
# 388 -- Cannot apply move 4 to cube 113. Cube would crash into neighbouring cubes. Skipping command...
# 389 -- Cannot apply move 1 to cube 101. Cube is connecting. Skipping command...
# 390 -- Cannot apply move 2 to cube 115. Cube is connecting. Skipping command...
# 391 -- Cannot apply move 5 to cube 103. Cube is connecting. Skipping command...
# 392 -- Cannot apply move 3 to cube 47. Cube is connecting. Skipping command...
# 393 -- Cannot apply move 4 to cube 8. Cube is connecting. Skipping command...
# 394 -- Cannot apply move 1 to cube 106. Cube is connecting. Skipping command...
# 395 -- Cannot apply move 0 to cube 52. Cube is connecting. Skipping command...
# 396 -- Cannot apply move 0 to cube 79. Cube would crash into neighbouring cubes. Skipping command...
# 397 -- Cannot apply move 1 to cube 88. Cube would crash into neighbouring cubes. Skipping command...
# 400 -- Cannot apply move 2 to cube 39. Cube is connecting. Skipping command...
# 401 -- Cannot apply move 0 to cube 85. Cube would crash into neighbouring cubes. Skipping command...
# 402 -- Cannot apply move 4 to cube 12. Cube is connecting. Skipping command...
# 403 -- Cannot apply move 2 to cube 62. Cube is connecting. Skipping command...
# 404 -- Cannot apply move 5 to cube 101. Cube is connecting. Skipping command...
# 406 -- Cannot apply move 4 to cube 30. Cube would crash into neighbouring cubes. Skipping command...
# 407 -- Cannot apply move 0 to cube 66. Cube is connecting. Skipping command...
# 411 -- Cannot apply move 4 to cube 49. Cube is connecting. Skipping command...
# 412 -- Cannot apply move 2 to cube 8. Cube is connecting. Skipping command...
# 413 -- Cannot apply move 2 to cube 116. Cube is connecting. Skipping command...
# 415 -- Cannot apply move 5 to cube 128. Cube would crash into neighbouring cubes. Skipping command...
# 416 -- Cannot apply move 1 to cube 104. Cube would crash into neighbouring cubes. Skipping command...
# 417 -- Cannot apply move 4 to cube 119. Cube would crash into neighbouring cubes. Skipping command...
# 419 -- Cannot apply move 4 to cube 44. Cube is connecting. Skipping command...
# 420 -- Cannot apply move 2 to cube 20. Cube would crash into neighbouring cubes. Skipping command...
# 421 -- Cannot apply move 4 to cube 4. Cube is connecting. Skipping command...
# 423 -- Cannot apply move 2 to cube 92. Cube is connecting. Skipping command...
# 424 -- Cannot apply move 1 to cube 68. Cube is connecting. Skipping command...
# 425 -- Cannot apply move 3 to cube 96. Cube is connecting. Skipping command...
# 426 -- Cannot apply move 3 to cube 132. Cube is connecting. Skipping command...
# 427 -- Cannot apply move 2 to cube 101. Cube is connecting. Skipping command...
# 428 -- Cannot apply move 3 to cube 133. Cube is connecting. Skipping command...
# 429 -- Cannot apply move 5 to cube 64. Cube is connecting. Skipping command...
# 430 -- Cannot apply move 0 to cube 36. Cube would crash into neighbouring cubes. Skipping command...
# 432 -- Cannot apply move 5 to cube 96. Cube is connecting. Skipping command...
# 433 -- Cannot apply move 5 to cube 62. Cube is connecting. Skipping command...
# 436 -- Cannot apply move 0 to cube 115. Cube is connecting. Skipping command...
# 438 -- Cannot apply move 5 to cube 46. Cube is connecting. Skipping command...
# 439 -- Cannot apply move 1 to cube 40. Cube is connecting. Skipping command...
# 440 -- Cannot apply move 3 to cube 146. Cube would crash into neighbouring cubes. Skipping command...
# 441 -- Cannot apply move 2 to cube 56. Cube is connecting. Skipping command...
# 442 -- Cannot apply move 3 to cube 53. Cube is connecting. Skipping command...
# 443 -- Cannot apply move 1 to cube 41. Cube is connecting. Skipping command...
# 445 -- Cannot apply move 4 to cube 143. Cube is connecting. Skipping command...
# 448 -- Cannot apply move 1 to cube 108. Cube is connecting. Skipping command...
# 449 -- Cannot apply move 4 to cube 92. Cube is connecting. Skipping command...
# 450 -- Cannot apply move 1 to cube 106. Cube is connecting. Skipping command...
# 451 -- Cannot apply move 2 to cube 13. Cube is connecting. Skipping command...
# 452 -- Cannot apply move 4 to cube 105. Cube is connecting. Skipping command...
# 453 -- Cannot apply move 4 to cube 97. Cube is connecting. Skipping command...
# 454 -- Cannot apply move 0 to cube 44. Cube is connecting. Skipping command...
# 456 -- Cannot apply move 5 to cube 54. Cube is connecting. Skipping command...
# 457 -- Cannot apply move 1 to cube 96. Cube is connecting. Skipping command...
# 458 -- Cannot apply move 5 to cube 49. Cube is connecting. Skipping command...
# 459 -- Cannot apply move 4 to cube 8. Cube is connecting. Skipping command...
# 460 -- Cannot apply move 4 to cube 13. Cube is connecting. Skipping command...
# 462 -- Cannot apply move 5 to cube 39. Cube is connecting. Skipping command...
# 463 -- Cannot apply move 5 to cube 37. Cube would crash into neighbouring cubes. Skipping command...
# 464 -- Cannot apply move 1 to cube 121. Cube is connecting. Skipping command...
# 465 -- Cannot apply move 0 to cube 44. Cube is connecting. Skipping command...
# 466 -- Cannot apply move 5 to cube 143. Cube is connecting. Skipping command...
# 467 -- Cannot apply move 4 to cube 36. Cube would crash into neighbouring cubes. Skipping command...
# 468 -- Cannot apply move 1 to cube 53. Cube is connecting. Skipping command...
# 469 -- Cannot apply move 5 to cube 73. Cube is connecting. Skipping command...
# 471 -- Cannot apply move 4 to cube 17. Cube is connecting. Skipping command...
# 472 -- Cannot apply move 4 to cube 91. Cube is connecting. Skipping command...
# 473 -- Cannot apply move 5 to cube 106. Cube is connecting. Skipping command...
# 475 -- Cannot apply move 1 to cube 59. Cube is connecting. Skipping command...
# 476 -- Cannot apply move 0 to cube 138. Cube is connecting. Skipping command...
# 477 -- Cannot apply move 4 to cube 114. Cube is connecting. Skipping command...
# 478 -- Cannot apply move 0 to cube 77. Cube would crash into neighbouring cubes. Skipping command...
# 479 -- Cannot apply move 0 to cube 120. Cube is connecting. Skipping command...
# 480 -- Cannot apply move 1 to cube 84. Cube is connecting. Skipping command...
# 481 -- Cannot apply move 1 to cube 50. Cube is connecting. Skipping command...
# 482 -- Cannot apply move 5 to cube 27. Cube is connecting. Skipping command...
# 484 -- Cannot apply move 5 to cube 84. Cube is connecting. Skipping command...
# 485 -- Cannot apply move 3 to cube 47. Cube is connecting. Skipping command...
# 486 -- Cannot apply move 3 to cube 129. Cube is connecting. Skipping command...
# 487 -- Cannot apply move 0 to cube 114. Cube is connecting. Skipping command...
# 488 -- Cannot apply move 3 to cube 67. Cube is connecting. Skipping command...
# 489 -- Cannot apply move 3 to cube 93. Cube would crash into neighbouring cubes. Skipping command...
# 490 -- Cannot apply move 4 to cube 24. Cube is connecting. Skipping command...
# 491 -- Cannot apply move 1 to cube 31. Cube is connecting. Skipping command...
# 492 -- Cannot apply move 3 to cube 80. Cube is connecting. Skipping command...
# 494 -- Cannot apply move 3 to cube 30. Cube would crash into neighbouring cubes. Skipping command...
# 495 -- Cannot apply move 1 to cube 115. Cube is connecting. Skipping command...
# 496 -- Cannot apply move 3 to cube 135. Cube is connecting. Skipping command...
# 497 -- Cannot apply move 4 to cube 56. Cube is connecting. Skipping command...
# 498 -- Cannot apply move 1 to cube 43. Cube is connecting. Skipping command...
# 499 -- Cannot apply move 2 to cube 69. Cube is connecting. Skipping command...
# 500 -- Cannot apply move 2 to cube 66. Cube is connecting. Skipping command...
# 501 -- Cannot apply move 2 to cube 129. Cube is connecting. Skipping command...
# 502 -- Cannot apply move 2 to cube 75. Cube is connecting. Skipping command...
# 506 -- Cannot apply move 4 to cube 2. Cube is connecting. Skipping command...
# 507 -- Cannot apply move 4 to cube 14. Cube is connecting. Skipping command...
# 508 -- Cannot apply move 5 to cube 97. Cube is connecting. Skipping command...
# 509 -- Cannot apply move 4 to cube 7. Cube is connecting. Skipping command...
# 510 -- Cannot apply move 5 to cube 33. Cube is connecting. Skipping command...
# 511 -- Cannot apply move 4 to cube 92. Cube is connecting. Skipping command...
# 512 -- Cannot apply move 3 to cube 131. Cube would crash into neighbouring cubes. Skipping command...
# 513 -- Cannot apply move 1 to cube 111. Cube would crash into neighbouring cubes. Skipping command...
# 515 -- Cannot apply move 1 to cube 66. Cube is connecting. Skipping command...
# 516 -- Cannot apply move 2 to cube 15. Cube is connecting. Skipping command...
# 517 -- Cannot apply move 4 to cube 100. Cube is connecting. Skipping command...
# 518 -- Cannot apply move 1 to cube 33. Cube is connecting. Skipping command...
# 519 -- Cannot apply move 0 to cube 107. Cube is connecting. Skipping command...
# 521 -- Cannot apply move 4 to cube 52. Cube is connecting. Skipping command...
# 522 -- Cannot apply move 1 to cube 91. Cube is connecting. Skipping command...
# 523 -- Cannot apply move 0 to cube 56. Cube is connecting. Skipping command...
# 524 -- Cannot apply move 3 to cube 75. Cube is connecting. Skipping command...
# 526 -- Cannot apply move 1 to cube 7. Cube is connecting. Skipping command...
# 527 -- Cannot apply move 2 to cube 128. Cube would crash into neighbouring cubes. Skipping command...
# 529 -- Cannot apply move 0 to cube 8. Cube is connecting. Skipping command...
# 530 -- Cannot apply move 0 to cube 17. Cube is connecting. Skipping command...
# 531 -- Cannot apply move 4 to cube 5. Cube is connecting. Skipping command...
# 532 -- Cannot apply move 1 to cube 106. Cube is connecting. Skipping command...
# 533 -- Cannot apply move 0 to cube 55. Cube is connecting. Skipping command...
# 534 -- Cannot apply move 0 to cube 124. Cube is connecting. Skipping command...
# 535 -- Cannot apply move 3 to cube 118. Cube is connecting. Skipping command...
# 536 -- Cannot apply move 2 to cube 47. Cube is connecting. Skipping command...
# 537 -- Cannot apply move 4 to cube 84. Cube is connecting. Skipping command...
# 538 -- Cannot apply move 4 to cube 11. Cube is connecting. Skipping command...
# 540 -- Cannot apply move 4 to cube 99. Cube is connecting. Skipping command...
# 541 -- Cannot apply move 2 to cube 46. Cube is connecting. Skipping command...
# 543 -- Cannot apply move 4 to cube 102. Cube is connecting. Skipping command...
# 545 -- Cannot apply move 1 to cube 69. Cube is connecting. Skipping command...
# 546 -- Cannot apply move 4 to cube 135. Cube is connecting. Skipping command...
# 548 -- Cannot apply move 0 to cube 102. Cube is connecting. Skipping command...
# 549 -- Cannot apply move 3 to cube 110. Cube would crash into neighbouring cubes. Skipping command...
# 551 -- Cannot apply move 5 to cube 105. Cube is connecting. Skipping command...
# 552 -- Cannot apply move 5 to cube 54. Cube is connecting. Skipping command...
# 553 -- Cannot apply move 2 to cube 146. Cube would crash into neighbouring cubes. Skipping command...
# 554 -- Cannot apply move 2 to cube 40. Cube is connecting. Skipping command...
# 555 -- Cannot apply move 3 to cube 14. Cube is connecting. Skipping command...
# 556 -- Cannot apply move 0 to cube 38. Cube is connecting. Skipping command...
# 557 -- Cannot apply move 5 to cube 76. Cube would crash into neighbouring cubes. Skipping command...
# 558 -- Cannot apply move 3 to cube 33. Cube is connecting. Skipping command...
# 559 -- Cannot apply move 0 to cube 129. Cube is connecting. Skipping command...
# 560 -- Cannot apply move 0 to cube 133. Cube is connecting. Skipping command...
# 561 -- Cannot apply move 0 to cube 51. Cube is connecting. Skipping command...
# 563 -- Cannot apply move 5 to cube 120. Cube is connecting. Skipping command...
# 564 -- Cannot apply move 1 to cube 47. Cube is connecting. Skipping command...
# 566 -- Cannot apply move 2 to cube 46. Cube is connecting. Skipping command...
# 568 -- Cannot apply move 1 to cube 58. Cube is connecting. Skipping command...
# 569 -- Cannot apply move 0 to cube 30. Cube would crash into neighbouring cubes. Skipping command...
# 570 -- Cannot apply move 0 to cube 30. Cube would crash into neighbouring cubes. Skipping command...
# 571 -- Cannot apply move 2 to cube 0. Cube would crash into neighbouring cubes. Skipping command...
# 572 -- Cannot apply move 4 to cube 32. Cube is connecting. Skipping command...
# 573 -- Cannot apply move 0 to cube 116. Cube is connecting. Skipping command...
# 574 -- Cannot apply move 1 to cube 24. Cube is connecting. Skipping command...
# 576 -- Cannot apply move 5 to cube 102. Cube is connecting. Skipping command...
# 577 -- Cannot apply move 3 to cube 27. Cube is connecting. Skipping command...
# 579 -- Cannot apply move 1 to cube 88. Cube would crash into neighbouring cubes. Skipping command...
# 580 -- Cannot apply move 4 to cube 138. Cube is connecting. Skipping command...
# 581 -- Cannot apply move 5 to cube 144. Cube is connecting. Skipping command...
# 583 -- Cannot apply move 5 to cube 21. Cube would crash into neighbouring cubes. Skipping command...
# 584 -- Cannot apply move 5 to cube 100. Cube is connecting. Skipping command...
# 586 -- Cannot apply move 0 to cube 72. Cube is connecting. Skipping command...
# 587 -- Cannot apply move 1 to cube 9. Cube is connecting. Skipping command...
# 588 -- Cannot apply move 5 to cube 105. Cube is connecting. Skipping command...
# 589 -- Cannot apply move 2 to cube 84. Cube is connecting. Skipping command...
# 590 -- Cannot apply move 5 to cube 43. Cube is connecting. Skipping command...
# 591 -- Cannot apply move 5 to cube 130. Cube would crash into neighbouring cubes. Skipping command...
# 592 -- Cannot apply move 4 to cube 68. Cube is connecting. Skipping command...
# 595 -- Cannot apply move 4 to cube 74. Cube is connecting. Skipping command...
# 597 -- Cannot apply move 3 to cube 114. Cube is connecting. Skipping command...
# 599 -- Cannot apply move 4 to cube 24. Cube is connecting. Skipping command...
# 601 -- Cannot apply move 0 to cube 132. Cube is connecting. Skipping command...
# 602 -- Cannot apply move 1 to cube 10. Cube would crash into neighbouring cubes. Skipping command...
# 603 -- Cannot apply move 1 to cube 19. Cube is connecting. Skipping command...
# 604 -- Cannot apply move 3 to cube 6. Cube is connecting. Skipping command...
# 605 -- Cannot apply move 4 to cube 105. Cube is connecting. Skipping command...
# 607 -- Cannot apply move 4 to cube 71. Cube is connecting. Skipping command...
# 608 -- Cannot apply move 2 to cube 46. Cube is connecting. Skipping command...
# 610 -- Cannot apply move 3 to cube 143. Cube is connecting. Skipping command...
# 611 -- Cannot apply move 5 to cube 71. Cube is connecting. Skipping command...
# 612 -- Cannot apply move 3 to cube 87. Cube would crash into neighbouring cubes. Skipping command...
# 614 -- Cannot apply move 0 to cube 3. Cube would crash into neighbouring cubes. Skipping command...
# 616 -- Cannot apply move 2 to cube 122. Cube is connecting. Skipping command...
# 618 -- Cannot apply move 2 to cube 67. Cube is connecting. Skipping command...
# 619 -- Cannot apply move 0 to cube 16. Cube is connecting. Skipping command...
# 620 -- Cannot apply move 3 to cube 5. Cube is connecting. Skipping command...
# 622 -- Cannot apply move 2 to cube 29. Cube is connecting. Skipping command...
# 623 -- Cannot apply move 4 to cube 145. Cube is connecting. Skipping command...
# 624 -- Cannot apply move 4 to cube 53. Cube is connecting. Skipping command...
# 625 -- Cannot apply move 0 to cube 29. Cube is connecting. Skipping command...
# 627 -- Cannot apply move 0 to cube 2. Cube is connecting. Skipping command...
# 628 -- Cannot apply move 0 to cube 117. Cube would crash into neighbouring cubes. Skipping command...
# 629 -- Cannot apply move 4 to cube 29. Cube is connecting. Skipping command...
# 630 -- Cannot apply move 1 to cube 21. Cube would crash into neighbouring cubes. Skipping command...
# 631 -- Cannot apply move 2 to cube 57. Cube would crash into neighbouring cubes. Skipping command...
# 632 -- Cannot apply move 3 to cube 129. Cube is connecting. Skipping command...
# 633 -- Cannot apply move 1 to cube 40. Cube is connecting. Skipping command...
# 634 -- Cannot apply move 0 to cube 124. Cube is connecting. Skipping command...
# 635 -- Cannot apply move 3 to cube 142. Cube is connecting. Skipping command...
# 636 -- Cannot apply move 4 to cube 102. Cube is connecting. Skipping command...
# 637 -- Cannot apply move 4 to cube 89. Cube is connecting. Skipping command...
# 638 -- Cannot apply move 5 to cube 71. Cube is connecting. Skipping command...
# 639 -- Cannot apply move 5 to cube 84. Cube is connecting. Skipping command...
# 640 -- Cannot apply move 1 to cube 116. Cube is connecting. Skipping command...
# 641 -- Cannot apply move 5 to cube 21. Cube would crash into neighbouring cubes. Skipping command...
# 643 -- Cannot apply move 0 to cube 137. Cube is connecting. Skipping command...
# 644 -- Cannot apply move 1 to cube 39. Cube is connecting. Skipping command...
# 646 -- Cannot apply move 3 to cube 42. Cube is connecting. Skipping command...
# 647 -- Cannot apply move 1 to cube 123. Cube is connecting. Skipping command...
# 648 -- Cannot apply move 3 to cube 59. Cube is connecting. Skipping command...
# 650 -- Cannot apply move 4 to cube 107. Cube is connecting. Skipping command...
# 651 -- Cannot apply move 0 to cube 113. Cube is connecting. Skipping command...
# 653 -- Cannot apply move 2 to cube 139. Cube would crash into neighbouring cubes. Skipping command...
# 654 -- Cannot apply move 5 to cube 15. Cube is connecting. Skipping command...
# 655 -- Cannot apply move 4 to cube 133. Cube is connecting. Skipping command...
# 656 -- Cannot apply move 3 to cube 34. Cube is connecting. Skipping command...
# 657 -- Cannot apply move 1 to cube 23. Cube is connecting. Skipping command...
# 658 -- Cannot apply move 5 to cube 131. Cube would crash into neighbouring cubes. Skipping command...
# 659 -- Cannot apply move 5 to cube 91. Cube is connecting. Skipping command...
# 660 -- Cannot apply move 1 to cube 40. Cube is connecting. Skipping command...
# 661 -- Cannot apply move 0 to cube 120. Cube is connecting. Skipping command...
# 662 -- Cannot apply move 2 to cube 14. Cube is connecting. Skipping command...
# 663 -- Cannot apply move 1 to cube 69. Cube is connecting. Skipping command...
# 664 -- Cannot apply move 1 to cube 63. Cube is connecting. Skipping command...
# 665 -- Cannot apply move 3 to cube 103. Cube is connecting. Skipping command...
# 666 -- Cannot apply move 3 to cube 90. Cube is connecting. Skipping command...
# 668 -- Cannot apply move 2 to cube 35. Cube would crash into neighbouring cubes. Skipping command...
# 669 -- Cannot apply move 5 to cube 92. Cube is connecting. Skipping command...
# 671 -- Cannot apply move 3 to cube 47. Cube is connecting. Skipping command...
# 672 -- Cannot apply move 5 to cube 33. Cube is connecting. Skipping command...
# 673 -- Cannot apply move 2 to cube 9. Cube is connecting. Skipping command...
# 674 -- Cannot apply move 3 to cube 8. Cube is connecting. Skipping command...
# 675 -- Cannot apply move 3 to cube 3. Cube would crash into neighbouring cubes. Skipping command...
# 679 -- Cannot apply move 2 to cube 50. Cube is connecting. Skipping command...
# 680 -- Cannot apply move 2 to cube 40. Cube is connecting. Skipping command...
# 681 -- Cannot apply move 5 to cube 52. Cube is connecting. Skipping command...
# 682 -- Cannot apply move 0 to cube 59. Cube is connecting. Skipping command...
# 683 -- Cannot apply move 1 to cube 142. Cube is connecting. Skipping command...
# 685 -- Cannot apply move 0 to cube 124. Cube is connecting. Skipping command...
# 686 -- Cannot apply move 2 to cube 102. Cube is connecting. Skipping command...
# 687 -- Cannot apply move 4 to cube 15. Cube is connecting. Skipping command...
# 690 -- Cannot apply move 1 to cube 125. Cube is connecting. Skipping command...
# 692 -- Cannot apply move 4 to cube 5. Cube is connecting. Skipping command...
# 694 -- Cannot apply move 4 to cube 38. Cube is connecting. Skipping command...
# 695 -- Cannot apply move 2 to cube 58. Cube is connecting. Skipping command...
# 696 -- Cannot apply move 2 to cube 137. Cube is connecting. Skipping command...
# 698 -- Cannot apply move 1 to cube 17. Cube is connecting. Skipping command...
# 699 -- Cannot apply move 3 to cube 132. Cube is connecting. Skipping command...
# 701 -- Cannot apply move 2 to cube 5. Cube is connecting. Skipping command...
# 702 -- Cannot apply move 0 to cube 131. Cube would crash into neighbouring cubes. Skipping command...
# 703 -- Cannot apply move 3 to cube 8. Cube is connecting. Skipping command...
# 704 -- Cannot apply move 5 to cube 99. Cube is connecting. Skipping command...
# 705 -- Cannot apply move 5 to cube 74. Cube is connecting. Skipping command...
# 706 -- Cannot apply move 1 to cube 144. Cube is connecting. Skipping command...
# 709 -- Cannot apply move 3 to cube 36. Cube would crash into neighbouring cubes. Skipping command...
# 710 -- Cannot apply move 5 to cube 113. Cube is connecting. Skipping command...
# 711 -- Cannot apply move 2 to cube 76. Cube is connecting. Skipping command...
# 712 -- Cannot apply move 3 to cube 118. Cube is connecting. Skipping command...
# 714 -- Cannot apply move 1 to cube 73. Cube is connecting. Skipping command...
# 715 -- Cannot apply move 1 to cube 144. Cube would crash into neighbouring cubes. Skipping command...
# 717 -- Cannot apply move 3 to cube 14. Cube is connecting. Skipping command...
# 718 -- Cannot apply move 0 to cube 83. Cube would crash into neighbouring cubes. Skipping command...
# 719 -- Cannot apply move 4 to cube 105. Cube is connecting. Skipping command...
# 722 -- Cannot apply move 1 to cube 16. Cube is connecting. Skipping command...
# 723 -- Cannot apply move 4 to cube 107. Cube is connecting. Skipping command...
# 724 -- Cannot apply move 4 to cube 46. Cube is connecting. Skipping command...
# 725 -- Cannot apply move 3 to cube 80. Cube is connecting. Skipping command...
# 726 -- Cannot apply move 3 to cube 42. Cube is connecting. Skipping command...
# 728 -- Cannot apply move 5 to cube 29. Cube is connecting. Skipping command...
# 729 -- Cannot apply move 2 to cube 58. Cube is connecting. Skipping command...
# 730 -- Cannot apply move 0 to cube 128. Cube is connecting. Skipping command...
# 731 -- Cannot apply move 1 to cube 53. Cube is connecting. Skipping command...
# 732 -- Cannot apply move 0 to cube 85. Cube would crash into neighbouring cubes. Skipping command...
# 735 -- Cannot apply move 5 to cube 111. Cube would crash into neighbouring cubes. Skipping command...
# 736 -- Cannot apply move 0 to cube 27. Cube is connecting. Skipping command...
# 737 -- Cannot apply move 3 to cube 15. Cube is connecting. Skipping command...
# 738 -- Cannot apply move 4 to cube 129. Cube is connecting. Skipping command...
# 740 -- Cannot apply move 3 to cube 31. Cube is connecting. Skipping command...
# 741 -- Cannot apply move 2 to cube 52. Cube is connecting. Skipping command...
# 743 -- Cannot apply move 0 to cube 143. Cube is connecting. Skipping command...
# 744 -- Cannot apply move 4 to cube 28. Cube is connecting. Skipping command...
# 746 -- Cannot apply move 2 to cube 91. Cube is connecting. Skipping command...
# 747 -- Cannot apply move 0 to cube 3. Cube would crash into neighbouring cubes. Skipping command...
# 750 -- Cannot apply move 4 to cube 115. Cube is connecting. Skipping command...
# 753 -- Cannot apply move 2 to cube 145. Cube is connecting. Skipping command...
# 754 -- Cannot apply move 5 to cube 145. Cube is connecting. Skipping command...
# 755 -- Cannot apply move 4 to cube 19. Cube is connecting. Skipping command...
# ...
# 5764 -- Cannot apply move 0 to cube 6. Cube is connecting. Skipping command...
# 5766 -- Cannot apply move 5 to cube 1. Cube is connecting. Skipping command...
# 5767 -- Cannot apply move 2 to cube 72. Cube is connecting. Skipping command...
# 5769 -- Cannot apply move 2 to cube 31. Cube would crash into neighbouring cubes. Skipping command...
# 5770 -- Cannot apply move 4 to cube 31. Cube would crash into neighbouring cubes. Skipping command...
# 5771 -- Cannot apply move 1 to cube 70. Cube is connecting. Skipping command...
# 5772 -- Cannot apply move 4 to cube 24. Cube is connecting. Skipping command...
# 5773 -- Cannot apply move 3 to cube 26. Cube is connecting. Skipping command...
# 5775 -- Cannot apply move 5 to cube 40. Cube is connecting. Skipping command...
# 5776 -- Cannot apply move 5 to cube 87. Cube is connecting. Skipping command...
# 5777 -- Cannot apply move 1 to cube 143. Cube is connecting. Skipping command...
# 5778 -- Cannot apply move 0 to cube 90. Cube is connecting. Skipping command...
# 5779 -- Cannot apply move 1 to cube 123. Cube is connecting. Skipping command...
# 5780 -- Cannot apply move 5 to cube 28. Cube is connecting. Skipping command...
# 5781 -- Cannot apply move 5 to cube 66. Cube is connecting. Skipping command...
# 5783 -- Cannot apply move 5 to cube 90. Cube is connecting. Skipping command...
# 5784 -- Cannot apply move 5 to cube 97. Cube is connecting. Skipping command...
# 5785 -- Cannot apply move 0 to cube 27. Cube would crash into neighbouring cubes. Skipping command...
# 5786 -- Cannot apply move 0 to cube 107. Cube would crash into neighbouring cubes. Skipping command...
# 5787 -- Cannot apply move 5 to cube 75. Cube is connecting. Skipping command...
# 5788 -- Cannot apply move 5 to cube 130. Cube would crash into neighbouring cubes. Skipping command...
# 5789 -- Cannot apply move 2 to cube 4. Cube is connecting. Skipping command...
# 5790 -- Cannot apply move 3 to cube 87. Cube is connecting. Skipping command...
# 5792 -- Cannot apply move 1 to cube 4. Cube is connecting. Skipping command...
# 5793 -- Cannot apply move 5 to cube 41. Cube is connecting. Skipping command...
# 5794 -- Cannot apply move 5 to cube 136. Cube would crash into neighbouring cubes. Skipping command...
# 5795 -- Cannot apply move 2 to cube 44. Cube would crash into neighbouring cubes. Skipping command...
# 5798 -- Cannot apply move 4 to cube 122. Cube is connecting. Skipping command...
# 5799 -- Cannot apply move 2 to cube 140. Cube would crash into neighbouring cubes. Skipping command...
# 5801 -- Cannot apply move 4 to cube 145. Cube is connecting. Skipping command...
# 5803 -- Cannot apply move 3 to cube 11. Cube would crash into neighbouring cubes. Skipping command...
# 5804 -- Cannot apply move 2 to cube 42. Cube would crash into neighbouring cubes. Skipping command...
# 5805 -- Cannot apply move 5 to cube 5. Cube is connecting. Skipping command...
# 5806 -- Cannot apply move 3 to cube 69. Cube is connecting. Skipping command...
# 5807 -- Cannot apply move 1 to cube 87. Cube is connecting. Skipping command...
# 5808 -- Cannot apply move 2 to cube 31. Cube is connecting. Skipping command...
# 5811 -- Cannot apply move 1 to cube 23. Cube is connecting. Skipping command...
# 5812 -- Cannot apply move 3 to cube 100. Cube is connecting. Skipping command...
# 5813 -- Cannot apply move 5 to cube 85. Cube would crash into neighbouring cubes. Skipping command...
# 5814 -- Cannot apply move 4 to cube 41. Cube is connecting. Skipping command...
# 5815 -- Cannot apply move 2 to cube 85. Cube would crash into neighbouring cubes. Skipping command...
# 5817 -- Cannot apply move 0 to cube 23. Cube is connecting. Skipping command...
# 5818 -- Cannot apply move 4 to cube 18. Cube would crash into neighbouring cubes. Skipping command...
# 5820 -- Cannot apply move 0 to cube 124. Cube would crash into neighbouring cubes. Skipping command...
# 5822 -- Cannot apply move 1 to cube 67. Cube is connecting. Skipping command...
# 5823 -- Cannot apply move 1 to cube 59. Cube is connecting. Skipping command...
# 5824 -- Cannot apply move 1 to cube 135. Cube would crash into neighbouring cubes. Skipping command...
# 5825 -- Cannot apply move 3 to cube 124. Cube would crash into neighbouring cubes. Skipping command...
# 5826 -- Cannot apply move 2 to cube 99. Cube would crash into neighbouring cubes. Skipping command...
# 5827 -- Cannot apply move 2 to cube 18. Cube would crash into neighbouring cubes. Skipping command...
# 5829 -- Cannot apply move 1 to cube 30. Cube is connecting. Skipping command...
# 5830 -- Cannot apply move 2 to cube 94. Cube is connecting. Skipping command...
# 5833 -- Cannot apply move 1 to cube 54. Cube would crash into neighbouring cubes. Skipping command...
# 5834 -- Cannot apply move 2 to cube 87. Cube is connecting. Skipping command...
# 5835 -- Cannot apply move 5 to cube 28. Cube is connecting. Skipping command...
# 5836 -- Cannot apply move 3 to cube 129. Cube is connecting. Skipping command...
# 5837 -- Cannot apply move 5 to cube 47. Cube is connecting. Skipping command...
# 5838 -- Cannot apply move 4 to cube 38. Cube would crash into neighbouring cubes. Skipping command...
# 5839 -- Cannot apply move 4 to cube 79. Cube is connecting. Skipping command...
# 5840 -- Cannot apply move 3 to cube 143. Cube is connecting. Skipping command...
# 5841 -- Cannot apply move 1 to cube 49. Cube would crash into neighbouring cubes. Skipping command...
# 5842 -- Cannot apply move 5 to cube 20. Cube is connecting. Skipping command...
# 5843 -- Cannot apply move 4 to cube 38. Cube would crash into neighbouring cubes. Skipping command...
# 5844 -- Cannot apply move 0 to cube 51. Cube is connecting. Skipping command...
# 5845 -- Cannot apply move 2 to cube 117. Cube is connecting. Skipping command...
# 5846 -- Cannot apply move 0 to cube 114. Cube is connecting. Skipping command...
# 5847 -- Cannot apply move 1 to cube 87. Cube is connecting. Skipping command...
# 5849 -- Cannot apply move 1 to cube 113. Cube is connecting. Skipping command...
# 5850 -- Cannot apply move 5 to cube 105. Cube is connecting. Skipping command...
# 5853 -- Cannot apply move 4 to cube 4. Cube is connecting. Skipping command...
# 5854 -- Cannot apply move 0 to cube 67. Cube is connecting. Skipping command...
# 5855 -- Cannot apply move 5 to cube 136. Cube would crash into neighbouring cubes. Skipping command...
# 5856 -- Cannot apply move 0 to cube 108. Cube is connecting. Skipping command...
# 5858 -- Cannot apply move 5 to cube 25. Cube is connecting. Skipping command...
# 5859 -- Cannot apply move 5 to cube 24. Cube is connecting. Skipping command...
# 5860 -- Cannot apply move 2 to cube 140. Cube would crash into neighbouring cubes. Skipping command...
# 5861 -- Cannot apply move 2 to cube 105. Cube is connecting. Skipping command...
# 5863 -- Cannot apply move 4 to cube 69. Cube is connecting. Skipping command...
# 5864 -- Cannot apply move 5 to cube 117. Cube is connecting. Skipping command...
# 5865 -- Cannot apply move 2 to cube 134. Cube is connecting. Skipping command...
# 5866 -- Cannot apply move 2 to cube 113. Cube is connecting. Skipping command...
# 5867 -- Cannot apply move 0 to cube 103. Cube is connecting. Skipping command...
# 5868 -- Cannot apply move 5 to cube 4. Cube is connecting. Skipping command...
# 5871 -- Cannot apply move 4 to cube 123. Cube is connecting. Skipping command...
# 5873 -- Cannot apply move 3 to cube 67. Cube is connecting. Skipping command...
# 5874 -- Cannot apply move 1 to cube 96. Cube is connecting. Skipping command...
# 5875 -- Cannot apply move 4 to cube 34. Cube is connecting. Skipping command...
# 5876 -- Cannot apply move 3 to cube 134. Cube is connecting. Skipping command...
# 5877 -- Cannot apply move 3 to cube 91. Cube is connecting. Skipping command...
# 5878 -- Cannot apply move 3 to cube 14. Cube is connecting. Skipping command...
# 5879 -- Cannot apply move 4 to cube 30. Cube is connecting. Skipping command...
# 5880 -- Cannot apply move 4 to cube 20. Cube is connecting. Skipping command...
# 5882 -- Cannot apply move 5 to cube 138. Cube is connecting. Skipping command...
# 5884 -- Cannot apply move 4 to cube 94. Cube is connecting. Skipping command...
# 5885 -- Cannot apply move 4 to cube 41. Cube is connecting. Skipping command...
# 5886 -- Cannot apply move 3 to cube 69. Cube is connecting. Skipping command...
# 5887 -- Cannot apply move 1 to cube 88. Cube is connecting. Skipping command...
# 5888 -- Cannot apply move 2 to cube 44. Cube would crash into neighbouring cubes. Skipping command...
# 5889 -- Cannot apply move 4 to cube 13. Cube is connecting. Skipping command...
# 5892 -- Cannot apply move 3 to cube 127. Cube is connecting. Skipping command...
# 5893 -- Cannot apply move 4 to cube 25. Cube is connecting. Skipping command...
# 5894 -- Cannot apply move 4 to cube 113. Cube is connecting. Skipping command...
# 5895 -- Cannot apply move 3 to cube 139. Cube is connecting. Skipping command...
# 5897 -- Cannot apply move 4 to cube 77. Cube is connecting. Skipping command...
# 5898 -- Cannot apply move 0 to cube 31. Cube is connecting. Skipping command...
# 5900 -- Cannot apply move 4 to cube 67. Cube is connecting. Skipping command...
# 5902 -- Cannot apply move 4 to cube 48. Cube would crash into neighbouring cubes. Skipping command...
# 5903 -- Cannot apply move 1 to cube 33. Cube is connecting. Skipping command...
# 5905 -- Cannot apply move 3 to cube 112. Cube is connecting. Skipping command...
# 5906 -- Cannot apply move 4 to cube 7. Cube is connecting. Skipping command...
# 5907 -- Cannot apply move 2 to cube 100. Cube is connecting. Skipping command...
# 5910 -- Cannot apply move 0 to cube 68. Cube is connecting. Skipping command...
# 5912 -- Cannot apply move 2 to cube 91. Cube is connecting. Skipping command...
# 5914 -- Cannot apply move 0 to cube 89. Cube is connecting. Skipping command...
# 5915 -- Cannot apply move 5 to cube 116. Cube is connecting. Skipping command...
# 5916 -- Cannot apply move 1 to cube 60. Cube would crash into neighbouring cubes. Skipping command...
# 5917 -- Cannot apply move 2 to cube 59. Cube is connecting. Skipping command...
# 5918 -- Cannot apply move 3 to cube 50. Cube is connecting. Skipping command...
# 5919 -- Cannot apply move 3 to cube 74. Cube is connecting. Skipping command...
# 5920 -- Cannot apply move 5 to cube 40. Cube is connecting. Skipping command...
# 5921 -- Cannot apply move 4 to cube 37. Cube is connecting. Skipping command...
# 5922 -- Cannot apply move 1 to cube 34. Cube is connecting. Skipping command...
# 5923 -- Cannot apply move 0 to cube 74. Cube is connecting. Skipping command...
# 5924 -- Cannot apply move 0 to cube 143. Cube is connecting. Skipping command...
# 5925 -- Cannot apply move 5 to cube 144. Cube is connecting. Skipping command...
# 5926 -- Cannot apply move 0 to cube 54. Cube would crash into neighbouring cubes. Skipping command...
# 5927 -- Cannot apply move 2 to cube 59. Cube is connecting. Skipping command...
# 5928 -- Cannot apply move 4 to cube 138. Cube is connecting. Skipping command...
# 5929 -- Cannot apply move 1 to cube 103. Cube is connecting. Skipping command...
# 5930 -- Cannot apply move 5 to cube 129. Cube is connecting. Skipping command...
# 5931 -- Cannot apply move 2 to cube 144. Cube is connecting. Skipping command...
# 5932 -- Cannot apply move 0 to cube 4. Cube is connecting. Skipping command...
# 5934 -- Cannot apply move 0 to cube 94. Cube is connecting. Skipping command...
# 5935 -- Cannot apply move 0 to cube 97. Cube is connecting. Skipping command...
# 5936 -- Cannot apply move 2 to cube 79. Cube is connecting. Skipping command...
# 5937 -- Cannot apply move 4 to cube 41. Cube is connecting. Skipping command...
# 5938 -- Cannot apply move 5 to cube 102. Cube is connecting. Skipping command...
# 5939 -- Cannot apply move 2 to cube 85. Cube would crash into neighbouring cubes. Skipping command...
# 5942 -- Cannot apply move 5 to cube 142. Cube is connecting. Skipping command...
# 5943 -- Cannot apply move 2 to cube 132. Cube is connecting. Skipping command...
# 5944 -- Cannot apply move 4 to cube 113. Cube is connecting. Skipping command...
# 5945 -- Cannot apply move 1 to cube 45. Cube is connecting. Skipping command...
# 5946 -- Cannot apply move 2 to cube 52. Cube would crash into neighbouring cubes. Skipping command...
# 5947 -- Cannot apply move 2 to cube 120. Cube is connecting. Skipping command...
# 5948 -- Cannot apply move 0 to cube 8. Cube is connecting. Skipping command...
# 5950 -- Cannot apply move 3 to cube 48. Cube would crash into neighbouring cubes. Skipping command...
# 5951 -- Cannot apply move 4 to cube 140. Cube would crash into neighbouring cubes. Skipping command...
# 5952 -- Cannot apply move 4 to cube 136. Cube would crash into neighbouring cubes. Skipping command...
# 5953 -- Cannot apply move 3 to cube 48. Cube would crash into neighbouring cubes. Skipping command...
# 5954 -- Cannot apply move 5 to cube 39. Cube is connecting. Skipping command...
# 5955 -- Cannot apply move 4 to cube 57. Cube is connecting. Skipping command...
# 5956 -- Cannot apply move 4 to cube 38. Cube would crash into neighbouring cubes. Skipping command...
# 5957 -- Cannot apply move 2 to cube 106. Cube is connecting. Skipping command...
# 5959 -- Cannot apply move 0 to cube 137. Cube is connecting. Skipping command...
# 5960 -- Cannot apply move 1 to cube 130. Cube is connecting. Skipping command...
# 5961 -- Cannot apply move 1 to cube 129. Cube is connecting. Skipping command...
# 5962 -- Cannot apply move 4 to cube 80. Cube would crash into neighbouring cubes. Skipping command...
# 5963 -- Cannot apply move 1 to cube 100. Cube is connecting. Skipping command...
# 5964 -- Cannot apply move 3 to cube 2. Cube would crash into neighbouring cubes. Skipping command...
# 5965 -- Cannot apply move 5 to cube 142. Cube is connecting. Skipping command...
# 5966 -- Cannot apply move 3 to cube 14. Cube is connecting. Skipping command...
# 5967 -- Cannot apply move 4 to cube 8. Cube is connecting. Skipping command...
# 5968 -- Cannot apply move 2 to cube 122. Cube is connecting. Skipping command...
# 5969 -- Cannot apply move 1 to cube 26. Cube is connecting. Skipping command...
# 5970 -- Cannot apply move 4 to cube 123. Cube is connecting. Skipping command...
# 5972 -- Cannot apply move 4 to cube 81. Cube would crash into neighbouring cubes. Skipping command...
# 5973 -- Cannot apply move 1 to cube 61. Cube would crash into neighbouring cubes. Skipping command...
# 5975 -- Cannot apply move 2 to cube 120. Cube is connecting. Skipping command...
# 5976 -- Cannot apply move 1 to cube 110. Cube would crash into neighbouring cubes. Skipping command...
# 5977 -- Cannot apply move 1 to cube 27. Cube is connecting. Skipping command...
# 5980 -- Cannot apply move 3 to cube 37. Cube is connecting. Skipping command...
# 5981 -- Cannot apply move 1 to cube 22. Cube would crash into neighbouring cubes. Skipping command...
# 5982 -- Cannot apply move 0 to cube 69. Cube is connecting. Skipping command...
# 5983 -- Cannot apply move 3 to cube 113. Cube is connecting. Skipping command...
# 5984 -- Cannot apply move 1 to cube 103. Cube is connecting. Skipping command...
# 5985 -- Cannot apply move 2 to cube 77. Cube is connecting. Skipping command...
# 5986 -- Cannot apply move 1 to cube 54. Cube would crash into neighbouring cubes. Skipping command...
# 5987 -- Cannot apply move 1 to cube 74. Cube is connecting. Skipping command...
# 5988 -- Cannot apply move 0 to cube 140. Cube is connecting. Skipping command...
# 5990 -- Cannot apply move 4 to cube 58. Cube is connecting. Skipping command...
# 5992 -- Cannot apply move 3 to cube 102. Cube is connecting. Skipping command...
# 5993 -- Cannot apply move 1 to cube 113. Cube is connecting. Skipping command...
# 5994 -- Cannot apply move 4 to cube 24. Cube is connecting. Skipping command...
# 5995 -- Cannot apply move 4 to cube 82. Cube would crash into neighbouring cubes. Skipping command...
# 5997 -- Cannot apply move 2 to cube 39. Cube is connecting. Skipping command...
# 5998 -- Cannot apply move 3 to cube 100. Cube is connecting. Skipping command...
# 5999 -- Cannot apply move 4 to cube 67. Cube is connecting. Skipping command...

# %% [markdown]
# The following functions removes these "illegal" moves!

# %%
# Function for removing illegal moves
def remove_illegal_moves_from_chromosome(chromosome):
    init = np.load('data/ISS/Initial_Config.npy')
    cubes = ProgrammableCubes(init)

    filtered_chromosome = []

    for i in range(int(len(chromosome)/2)):
        cube_id = chromosome[i*2]
        move = chromosome[i*2+1]
        done = cubes.apply_single_update_step(cube_id, move)
        # done is 1 if the move is legal and 0 otherwise
        if done == 1:
            filtered_chromosome += [cube_id, move]
    # The part to be evaluated by the fitness function ends here,
    # thus we add -1
    filtered_chromosome += [-1]
    
    # Fill up the remaining chromosome with 0s (will not be evaluated)
    if len(filtered_chromosome) < 12001:
        for i in range(12000 - len(filtered_chromosome)):
            filtered_chromosome += [0]
        # Mandatory entry of -1 at the very end
        filtered_chromosome += [-1]
        
    return np.array(filtered_chromosome)

# clean the chromosome!
cleaned_chromosome = remove_illegal_moves_from_chromosome(chromosome)

# and run it again!
udp = programmable_cubes_UDP('ISS')
prob = problem(udp)
prob.fitness(cleaned_chromosome)
# Out:
# array([0.08350676])

# %% [markdown]
# The fitness improved because the evaluated part of the chromosome got shorter! Always remove unnecessary moves from your solution before submitting it!

# %% [markdown]
# #### However, we could also directly create a chromosome that only contains legal moves
#
# This is slower though, as we have to go through the logic of checking moves!

# %%
# New function for creating a chromosome without illegal moves
def create_chromosome_with_legal_moves_only():
    init = np.load('data/ISS/Initial_Config.npy')
    cubes = ProgrammableCubes(init)

    chromosome = []

    while len(chromosome) < 12000:
        cube_id = np.random.randint(148)
        move = np.random.randint(6)
        done = cubes.apply_single_update_step(cube_id, move)
        if done == 1:
            chromosome += [cube_id, move]
    chromosome += [-1]
        
    return np.array(chromosome)
    
# create your chromosome
full_chrom = create_chromosome_with_legal_moves_only()

# and run it!
udp = programmable_cubes_UDP('ISS')
prob = problem(udp)
prob.fitness(full_chrom)
# Out:
# array([0.1622575])

# %% [markdown]
# #### If you like, you can also animate your solution :)

# %%
# Lets load the initial data
init = np.load('data/ISS/Initial_Config.npy')
cube_types = np.load('data/ISS/Initial_Cube_Types.npy')
cubes = ProgrammableCubes(deepcopy(init))

# Function to turn the sparse cube representation into a dense one (for plotting only)
def coords_to_dense(positions, cube_types):
    cube_tensor = np.zeros((3, 30,30,30))
    for l in range(len(cube_types)):
        for pos in positions[cube_types == l]:
            i,j,k = pos
            cube_tensor[l][i+10][j+10][k+10] = 1
    return cube_tensor

# store cube configs to be plotted
storage = [coords_to_dense(cubes.cube_position, cube_types)]

# apply moves and store results for plotting
steps = 0
tobreak = False
for j in range(int(len(cleaned_chromosome)/2)):
    cube_id = cleaned_chromosome[2*j]
    move = cleaned_chromosome[2*j+1]
    if cube_id == -1:
        break
    done = cubes.apply_single_update_step(cube_id, move, verbose=True)
    steps += done
    storage.append(coords_to_dense(cubes.cube_position, cube_types))

# %% [markdown]
# Lets go!

# %%
plt.rcParams['figure.dpi'] = 100
plt.rcParams['savefig.bbox'] = 'tight'
with open('problems/ISS.json') as infile:
    colours = json.load(infile)['colours']


fig = plt.figure(figsize=(plt.figaspect(1)))
ax = fig.add_subplot(1, 1, 1, projection='3d')
sns.despine(ax=ax, bottom=True,top=True,left=True,right=True)
ln, = ax.plot3D([0], [0], [0])
ax._axis3don = False
ax.set_facecolor('white')
        
def init():
    return ln,

def update(kk):
    ax.clear()
    for l in range(3):
        ax.voxels(storage[kk][l], facecolor = colours[l], edgecolors = 'k', alpha=.4)
    ax.axis('off')
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_zticks([])
    ax.set_title('{}'.format(kk))
    ax._axis3don = False
    plt.tight_layout()

# to speed it up, we only show the ensemble after each 100th move. 
# Choose a smaller number than 100 to show more intermediate moves!
ani = FuncAnimation(fig, update, frames=np.arange(0,len(storage),100),
                    init_func=init, interval=1000., blit=True)
# ani.save('ISS.gif')
# Out:
# <img src="data:image/png;base64,..." width="480">

# %% [markdown]
# #### Also: you might not always want to start from the beginning to speed things up!
#
# You can start evaluation from a custom configuration instead! For instance, here we start from the target configuration (although cube types do not match, so the fitness can still be improved!):

# %%
udp.fitness(np.array([-1]), initial_configuration=udp.target_cube_positions)
# Out:
# [-0.6716549295774648]

# %% [markdown]
# ### Now lets do the same for James Webb!

# %%
def create_random_chromosome():
    chrom = []
    for i in range(30000):
        cube_id = np.random.randint(643)
        move = np.random.randint(6)

        chrom += [cube_id, move]
    chrom += [-1]
    return np.array(chrom)

chromosome = create_random_chromosome()

udp = programmable_cubes_UDP('JWST')
prob = problem(udp)
prob.fitness(chromosome)
# Out:
# array([0.18488889])

# %%
udp.fitness(chromosome)
udp.plot('target', [3,4,5])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
udp.plot('ensemble', [3,4,5])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### And for the Enterprise!

# %%
def create_random_chromosome():
    chrom = []
    for i in range(100000):
        cube_id = np.random.randint(1472)
        move = np.random.randint(6)

        chrom += [cube_id, move]
    chrom += [-1]
    return np.array(chrom)

chromosome = create_random_chromosome()

udp = programmable_cubes_UDP('Enterprise')

# %%
udp.fitness(np.array([-1]))
udp.plot('target', [1,2,3,5,6,7,8,9])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
udp.plot('ensemble', [1,2,3,5,6,7,8,9])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ##### Now you know the basics :) Good luck and have fun!!
